# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = "/content/drive/MyDrive/S&P Crypto Project/Market Sentiment Data/3. Bitcoin Annulized Volatility.csv"
df = pd.read_csv(file)
# df.drop(['symbol'], axis=1)
df.columns
# Out:
# Index(['symbol', 'timestamp', 'price.BVOL', 'price.XBT30M'], dtype='object')

# %%
df.drop(['symbol'],axis=1,inplace=True)
df
# Out:
#                    timestamp  price.BVOL  price.XBT30M
# 0   2023-01-23T12:00:00.000Z       16.35      22938.10
# 1   2023-01-22T12:00:00.000Z       16.33      22759.64
# 2   2023-01-21T12:00:00.000Z       16.05      22864.88
# 3   2023-01-20T12:00:00.000Z       13.83      22879.35
# 4   2023-01-19T12:00:00.000Z       13.80      22702.45
# ..                       ...         ...           ...
# 95  2022-10-20T12:00:00.000Z       18.28      16934.26
# 96  2022-10-19T12:00:00.000Z       18.83      16943.50
# 97  2022-10-18T12:00:00.000Z       19.65      16938.68
# 98  2022-10-17T12:00:00.000Z       19.72      16936.17
# 99  2022-10-16T12:00:00.000Z       19.74      16917.30
#
# [100 rows x 3 columns]

# %%
df['timestamp'] = df['timestamp'].apply(lambda x: x[:10])
df['date'] = pd.to_datetime(df['timestamp'])
df.drop(['timestamp'], axis=1, inplace=True)
df.sort_values(by=['date'],inplace=True)
df
# Out:
#     price.BVOL  price.XBT30M       date
# 99       19.74      16917.30 2022-10-16
# 98       19.72      16936.17 2022-10-17
# 97       19.65      16938.68 2022-10-18
# 96       18.83      16943.50 2022-10-19
# 95       18.28      16934.26 2022-10-20
# ..         ...           ...        ...
# 4        13.80      22702.45 2023-01-19
# 3        13.83      22879.35 2023-01-20
# 2        16.05      22864.88 2023-01-21
# 1        16.33      22759.64 2023-01-22
# 0        16.35      22938.10 2023-01-23
#
# [100 rows x 3 columns]

# %%
df.set_index('date',inplace=True)
df.to_csv("/content/drive/MyDrive/S&P Crypto Project/Market Sentiment Data/3.BTC_annual_vol_v2.csv")

# %%
df1 = interpolate_index(file1,6)
df1.to_csv("/content/drive/MyDrive/S&P Crypto Project/Crypto Data/SP_BDM_exlarge_v2.csv")
df2 = interpolate_index(file2,6)
df2.to_csv("/content/drive/MyDrive/S&P Crypto Project/Crypto Data/SP_BDM_v2.csv")

# %%
file3 = "/content/drive/MyDrive/S&P Crypto Project/Market Sentiment Data/4. S&P 500 twitter sentiment index.xls"
df3 = interpolate_index(file3,6)
df3.to_csv("/content/drive/MyDrive/S&P Crypto Project/Market Sentiment Data/4.s&p_twitter_v2.csv")
